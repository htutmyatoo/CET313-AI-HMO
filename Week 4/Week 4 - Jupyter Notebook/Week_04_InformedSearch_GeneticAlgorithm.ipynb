# %% [markdown]
# # Week 4 - Informed Search (Genetic Algorithm) Lab Exercises
# ## Exercise 11

# %%
import random 
# Number of individuals in each generation 
POPULATION_SIZE = 4 
# Valid genes 
GENES = '''01''' 
# Target string to be generated 
TARGET = "001010"

class Individual (object):
    #Class representing individual in population 
    def __init__(self, chromosome):
        self.chromosome = chromosome 
        self.fitness = self.cal_fitness()
    @classmethod
    def mutated_genes(self):
        #create random genes for mutation global GENES
        gene = random.choice(GENES)
        return gene
    @classmethod
    def create_gnome (self):
        #create chromosome or string of genes global TARGET
        gnome_len = len (TARGET)
        return [self.mutated_genes() for _ in range(gnome_len)] 
    def mate(self, par2):
        #Perform mating and produce new offspring
        # chromosome for offspring
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome): 
            # random probability
            prob = random.random()
            # if prob is less than 0.45, insert gene from parent 1 
            if prob < 0.45:
                child_chromosome.append(gp1)
            # if prob is between 0.45 and 0.90, insert gene from parent 2 
            elif prob < 0.90:
                child_chromosome.append(gp2)
            # otherwise insert random gene (mutate),
            # for maintaining diversity
            else:
                child_chromosome.append(self.mutated_genes())
        # create new Individual(offspring) using generated chromosome for offspring 
        return Individual(child_chromosome)
        
    def cal_fitness(self):
        ''' Calculate fitness score, it is the number of characters in string 
which differ from target string.'''
        global TARGET
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt: fitness+= 1
        return fitness

# Driver code
def main():
    global POPULATION_SIZE
    #current generation
    generation = 1
    found = False
    population = []
    # create initial population
    for _ in range(POPULATION_SIZE):
        gnome = Individual.create_gnome() 
        population.append(Individual(gnome))
    while not found:
        # sort the population in increasing order of fitness score 
        population = sorted(population, key = lambda x:x.fitness) 
        # if the individual having lowest fitness score ie. 
        # 0 then we know that we have reached to the target 
        # and break the loop
        if population[0].fitness <= 0:
            found = True
            break
        # Otherwise generate new offsprings for new generation 
        new_generation = []
        # Perform Elitism, that mean 10% of fittest population 
        # goes to the next generation
        s = int((10*POPULATION_SIZE)/100) 
        new_generation.extend(population[:s])
        # From 50% of fittest population, Individuals
        # will mate to produce offspring
        s = int((90*POPULATION_SIZE)/100)
        for _ in range(s):
            parent1 = random.choice (population[:50]) 
            parent2 = random.choice (population[:50]) 
            child = parent1.mate(parent2)
            new_generation.append(child)
        
        population = new_generation
            
        print("Generation: {}\tString: {}\tFitness: {}".format(generation, "".join(population[0].chromosome),population[0].fitness))
        generation += 1
    print("Generation: {}\tString: {}\tFitness: {}".format(generation, "".join(population[0].chromosome),population[0].fitness))
            
if __name__ == '__main__': 
    main()
# Out:
# Generation: 1	String: 000100	Fitness: 3
# Generation: 2	String: 001110	Fitness: 1
# Generation: 3	String: 001110	Fitness: 1
# Generation: 4	String: 001100	Fitness: 2
# Generation: 5	String: 001110	Fitness: 1
# Generation: 6	String: 001100	Fitness: 2
# Generation: 7	String: 001110	Fitness: 1
# Generation: 8	String: 001110	Fitness: 1
# Generation: 9	String: 001110	Fitness: 1
# Generation: 10	String: 001111	Fitness: 2
# Generation: 11	String: 001000	Fitness: 1
# Generation: 12	String: 001000	Fitness: 1
# Generation: 13	String: 001111	Fitness: 2
# Generation: 14	String: 001111	Fitness: 2
# Generation: 15	String: 001100	Fitness: 2
# Generation: 16	String: 001101	Fitness: 3
# Generation: 17	String: 001010	Fitness: 0

# %% [markdown]
# ## Exercise 12: Change the problem to have all the alphabets and update the target value to be ‘Welcome to AI’

# %%
import random

# Number of individuals in each generation
POPULATION_SIZE = 90

# Valid genes (all alphabet characters including space)
GENES = 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ '

# Target string to be generated
TARGET = "Welcome to AI"

class Individual(object):
    # Class representing individual in population
    def __init__(self, chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()

    @classmethod
    def mutated_genes(cls):
        # Create random genes for mutation
        gene = random.choice(GENES)
        return gene

    @classmethod
    def create_gnome(cls):
        # Create chromosome or string of genes
        gnome_len = len(TARGET)
        return [cls.mutated_genes() for _ in range(gnome_len)]

    def mate(self, par2):
        # Perform mating and produce new offspring
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):
            # Random probability
            prob = random.random()
            # If prob is less than 0.45, insert gene from parent 1
            if prob < 0.45:
                child_chromosome.append(gp1)
            # If prob is between 0.45 and 0.90, insert gene from parent 2
            elif prob < 0.90:
                child_chromosome.append(gp2)
            # Otherwise insert random gene (mutate),
            # for maintaining diversity
            else:
                child_chromosome.append(self.mutated_genes())
        # Create new Individual (offspring) using generated chromosome for offspring
        return Individual(child_chromosome)

    def cal_fitness(self):
        ''' Calculate fitness score, it is the number of characters in string
        which differ from target string. '''
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt:
                fitness += 1
        return fitness

# Driver code
def main():
    global POPULATION_SIZE
    # Current generation
    generation = 1
    found = False
    population = []
    # Create initial population
    for _ in range(POPULATION_SIZE):
        gnome = Individual.create_gnome()
        population.append(Individual(gnome))
    
    while not found:
        # Sort the population in increasing order of fitness score
        population = sorted(population, key=lambda x: x.fitness)
        
        # If the individual having lowest fitness score is 0, we have reached the target
        if population[0].fitness <= 0:
            found = True
            break

        # Otherwise generate new offsprings for new generation
        new_generation = []
        
        # Perform Elitism, that means 10% of fittest population
        # goes to the next generation
        s = int((10 * POPULATION_SIZE) / 100)
        new_generation.extend(population[:s])
        
        # From 50% of fittest population, individuals
        # will mate to produce offspring
        s = int((90 * POPULATION_SIZE) / 100)
        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)
        
        population = new_generation

        print("Generation: {}\tString: {}\tFitness: {}".format(generation, "".join(population[0].chromosome), population[0].fitness))
        generation += 1

    print("Generation: {}\tString: {}\tFitness: {}".format(generation, "".join(population[0].chromosome), population[0].fitness))

if __name__ == '__main__':
    main()
# Out:
# Generation: 1	String: CDRBdmDeKLSAk	Fitness: 11
# Generation: 2	String: v eaoEvjooyAF	Fitness: 10
# Generation: 3	String: v eaoEvjooyAF	Fitness: 10
# Generation: 4	String: v eaoEvjooyAF	Fitness: 10
# Generation: 5	String: WTlEPmDeTBQAY	Fitness: 9
# Generation: 6	String: xKlaoAv BoUAs	Fitness: 8
# Generation: 7	String: WDtpomebpoSAw	Fitness: 7
# Generation: 8	String: WDtpomebpoSAw	Fitness: 7
# Generation: 9	String: WDtpomebpoSAw	Fitness: 7
# Generation: 10	String: yKlbome BouAP	Fitness: 6
# Generation: 11	String: yKlbome BouAP	Fitness: 6
# Generation: 12	String: WAlxome BoUAs	Fitness: 5
# Generation: 13	String: WAlxome BoUAs	Fitness: 5
# Generation: 14	String: WAlxome BoUAs	Fitness: 5
# Generation: 15	String: WAlxome BoUAs	Fitness: 5
# Generation: 16	String: WAlxome BoUAs	Fitness: 5
# Generation: 17	String: WAlxome BoUAs	Fitness: 5
# Generation: 18	String: WAlxome BoUAs	Fitness: 5
# Generation: 19	String: Wil ome BoUAI	Fitness: 4
# Generation: 20	String: Wil ome BoUAI	Fitness: 4
# Generation: 21	String: Wil ome BoUAI	Fitness: 4
# Generation: 22	String: Wil ome BoUAI	Fitness: 4
# Generation: 23	String: Wil ome BoUAI	Fitness: 4
# Generation: 24	String: Wil ome BoUAI	Fitness: 4
# Generation: 25	String: WelUome yoAAI	Fitness: 3
# Generation: 26	String: WelUome yoAAI	Fitness: 3
# Generation: 27	String: WelUome yoAAI	Fitness: 3
# Generation: 28	String: WelUome yoAAI	Fitness: 3
# Generation: 29	String: WelUome yoAAI	Fitness: 3
# Generation: 30	String: WelUome yoAAI	Fitness: 3
# Generation: 31	String: WelUome yoAAI	Fitness: 3
# Generation: 32	String: WelUome yoAAI	Fitness: 3
# Generation: 33	String: WelUome yoAAI	Fitness: 3
# Generation: 34	String: WelUome yoAAI	Fitness: 3
# Generation: 35	String: WelTome tozAI	Fitness: 2
# Generation: 36	String: WelTome tozAI	Fitness: 2
# Generation: 37	String: WelTome tozAI	Fitness: 2
# Generation: 38	String: WelTome tozAI	Fitness: 2
# Generation: 39	String: WelTome tozAI	Fitness: 2
# Generation: 40	String: WelTome tozAI	Fitness: 2
# Generation: 41	String: WelTome to AI	Fitness: 1
# Generation: 42	String: WelTome to AI	Fitness: 1
# Generation: 43	String: WelTome to AI	Fitness: 1
# Generation: 44	String: WelTome to AI	Fitness: 1
# Generation: 45	String: WelTome to AI	Fitness: 1
# Generation: 46	String: WelTome to AI	Fitness: 1
# Generation: 47	String: WelTome to AI	Fitness: 1
# Generation: 48	String: WelTome to AI	Fitness: 1
# Generation: 49	String: Welcome to AI	Fitness: 0

# %% [markdown]
# ## Exercise 13: Update the script to have so that it would measure the duration to find the solution.

# %%
import random
import time

# Number of individuals in each generation
POPULATION_SIZE = 200

# Valid genes (all alphabet characters including space)
GENES = 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ '

# Target string to be generated
TARGET = "Welcome to AI"

class Individual(object):
    # Class representing individual in population
    def __init__(self, chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()

    @classmethod
    def mutated_genes(cls):
        # Create random genes for mutation
        gene = random.choice(GENES)
        return gene

    @classmethod
    def create_gnome(cls):
        # Create chromosome or string of genes
        gnome_len = len(TARGET)
        return [cls.mutated_genes() for _ in range(gnome_len)]

    def mate(self, par2):
        # Perform mating and produce new offspring
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):
            # Random probability
            prob = random.random()
            # If prob is less than 0.45, insert gene from parent 1
            if prob < 0.45:
                child_chromosome.append(gp1)
            # If prob is between 0.45 and 0.90, insert gene from parent 2
            elif prob < 0.90:
                child_chromosome.append(gp2)
            # Otherwise insert random gene (mutate), for maintaining diversity
            else:
                child_chromosome.append(self.mutated_genes())
        # Create new Individual(offspring) using generated chromosome for offspring
        return Individual(child_chromosome)

    def cal_fitness(self):
        '''
        Calculate fitness score, it is the number of characters in string
        which differ from target string.
        '''
        global TARGET
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt:
                fitness += 1
        return fitness


# Driver code
def main():
    global POPULATION_SIZE
    # Start time measurement
    start_time = time.time()

    # Current generation
    generation = 1
    found = False
    population = []

    # Create initial population
    for _ in range(POPULATION_SIZE):
        gnome = Individual.create_gnome()
        population.append(Individual(gnome))

    while not found:
        # Sort the population in increasing order of fitness score
        population = sorted(population, key=lambda x: x.fitness)

        # If the individual having lowest fitness score ie. 0 then we know that we have reached to the target
        # and break the loop
        if population[0].fitness <= 0:
            found = True
            break

        # Otherwise generate new offsprings for new generation
        new_generation = []

        # Perform Elitism, that means 10% of fittest population goes to the next generation
        s = int((10 * POPULATION_SIZE) / 100)
        new_generation.extend(population[:s])

        # From 50% of fittest population, Individuals will mate to produce offspring
        s = int((90 * POPULATION_SIZE) / 100)
        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)

        population = new_generation

        print(
            "Generation: {}\tString: {}\tFitness: {}".format(
                generation, "".join(population[0].chromosome), population[0].fitness
            )
        )
        generation += 1

    # End time measurement
    end_time = time.time()

    print(
        "Generation: {}\tString: {}\tFitness: {}".format(
            generation, "".join(population[0].chromosome), population[0].fitness
        )
    )
    print(f"Time taken to find solution: {end_time - start_time:.2f} seconds")

if __name__ == "__main__":
    main()
# Out:
# Generation: 1	String: mxMriCeuzoNjb	Fitness: 11
# Generation: 2	String: SdtQpWg xZ Ab	Fitness: 10
# Generation: 3	String: WHTTYQWjtn AT	Fitness: 9
# Generation: 4	String: WetToQeRtndAT	Fitness: 7
# Generation: 5	String: WetFoQe QG Az	Fitness: 6
# Generation: 6	String: bsToome to MI	Fitness: 5
# Generation: 7	String: WeXQoQe tG AI	Fitness: 4
# Generation: 8	String: peMcoye to AI	Fitness: 3
# Generation: 9	String: Wegcome to EI	Fitness: 2
# Generation: 10	String: Wegcome to AI	Fitness: 1
# Generation: 11	String: Welcome to AI	Fitness: 0
# Time taken to find solution: 0.02 seconds

# %% [markdown]
# ## Exercise 14: Change the target to be 5 words and check how long would it take.

# %%
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ '''

TARGET = "I am Htut Myat Oo"

if __name__ == "__main__":
    main()
# Out:
# Generation: 1	String: IpxmepAZAdByFieaQ	Fitness: 14
# Generation: 2	String: rVaeLHSridGN p OX	Fitness: 13
# Generation: 3	String: rVaeKHSuidEYKv OX	Fitness: 12
# Generation: 4	String: HmSmkHyWtxMjatIBN	Fitness: 11
# Generation: 5	String: dakmsLiutaKyBtNOo	Fitness: 10
# Generation: 6	String: RrGmIPruxUcyat Oo	Fitness: 9
# Generation: 7	String: EjGm GrunaWyat Oo	Fitness: 8
# Generation: 8	String: HkamHHYutwMyat Og	Fitness: 6
# Generation: 9	String: HkamHHYutwMyat Og	Fitness: 6
# Generation: 10	String: Haam HtutwMyat Og	Fitness: 4
# Generation: 11	String: U am Htut Myatnoo	Fitness: 3
# Generation: 12	String: U am Htut Myatnoo	Fitness: 3
# Generation: 13	String: U am Htut Myatnoo	Fitness: 3
# Generation: 14	String: E am Htut Mybt Oo	Fitness: 2
# Generation: 15	String: E am Htut Mybt Oo	Fitness: 2
# Generation: 16	String: E am Htut Myat Oo	Fitness: 1
# Generation: 17	String: E am Htut Myat Oo	Fitness: 1
# Generation: 18	String: E am Htut Myat Oo	Fitness: 1
# Generation: 19	String: E am Htut Myat Oo	Fitness: 1
# Generation: 20	String: E am Htut Myat Oo	Fitness: 1
# Generation: 21	String: E am Htut Myat Oo	Fitness: 1
# Generation: 22	String: I am Htut Myat Oo	Fitness: 0
# Time taken to find solution: 0.04 seconds

# %% [markdown]
# ## Exercise 15: Change the alphabets to have numbers and letters and repeat the previous exercise.

# %%
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789 '''

TARGET = "I am Htut Myat Oo"

if __name__ == "__main__":
    main()
# Out:
# Generation: 1	String: lR72SOiGX TdXtusm	Fitness: 15
# Generation: 2	String: bnHwkjtatZdnmtQrm	Fitness: 14
# Generation: 3	String: fhIvb0jXttMsLtyOn	Fitness: 13
# Generation: 4	String: by7QHHtk68Mq8t b0	Fitness: 12
# Generation: 5	String: cSXptHtTt5MNHt 7w	Fitness: 11
# Generation: 6	String: zyaT HtofRM18t by	Fitness: 10
# Generation: 7	String: cOaD HtFt MFEt hw	Fitness: 8
# Generation: 8	String: Wvap HtutPMsat V0	Fitness: 7
# Generation: 9	String: Wvap HtutPMsat V0	Fitness: 7
# Generation: 10	String: c4a5 Htut Myat Mw	Fitness: 5
# Generation: 11	String: c4a5 Htut Myat Mw	Fitness: 5
# Generation: 12	String: 5MaD Htut MyatWOo	Fitness: 4
# Generation: 13	String: dsam HtutZMyat Oo	Fitness: 3
# Generation: 14	String: dsam HtutZMyat Oo	Fitness: 3
# Generation: 15	String: n9am Htut Myat Oo	Fitness: 2
# Generation: 16	String: n9am Htut Myat Oo	Fitness: 2
# Generation: 17	String: n9am Htut Myat Oo	Fitness: 2
# Generation: 18	String: n9am Htut Myat Oo	Fitness: 2
# Generation: 19	String: IMam Htut Myat Oo	Fitness: 1
# Generation: 20	String: IMam Htut Myat Oo	Fitness: 1
# Generation: 21	String: IMam Htut Myat Oo	Fitness: 1
# Generation: 22	String: IMam Htut Myat Oo	Fitness: 1
# Generation: 23	String: IMam Htut Myat Oo	Fitness: 1
# Generation: 24	String: IMam Htut Myat Oo	Fitness: 1
# Generation: 25	String: IMam Htut Myat Oo	Fitness: 1
# Generation: 26	String: I am Htut Myat Oo	Fitness: 0
# Time taken to find solution: 0.05 seconds
