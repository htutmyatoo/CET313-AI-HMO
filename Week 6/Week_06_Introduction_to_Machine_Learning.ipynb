# %% [markdown]
# # Week 6 - Introduction to Machine Learning
# ## Exercise 1: Answer the quiz available via canvas.

# %% [markdown]
# ![image.png](attachment:9dfb33d0-080b-4d65-b66f-ce3434d6a31b.png)

# %% [markdown]
# ## Exercise 2: Install the required libraries and its dependences.

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in d:\programdata\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in d:\programdata\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\programdata\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\programdata\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\programdata\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in d:\programdata\anaconda3\lib\site-packages (1.26.4)

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in d:\programdata\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\programdata\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\programdata\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in d:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in d:\programdata\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\programdata\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\programdata\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\programdata\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in d:\programdata\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in d:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in d:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in d:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\programdata\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %% [markdown]
# ## Exercise 3: Please download the dataset (in Zip format) and extract all the files in it. Inside the folder you will find another Zip file (named student) also Unzip it. Then copy the student-mat csv file to the same folder as your Jupiter notebook.
# ![image.png](attachment:81f8d4b8-1d7b-4034-832f-c21d8e082752.png)

# %% [markdown]
# ## Exercise 4: You can open the file using MS excel to check its content.
# ![image.png](attachment:480afdd4-188a-4491-99b7-5c268026e242.png)

# %% [markdown]
# ## Exercise 5: To open the dataset, we will be using Pandas library. Thus, initially we need to import the necessary libraries:

# %%
import pandas as pd

file_name = 'student-mat.csv'

df = pd.read_csv(file_name, sep=';') 

display(df.head())
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
print(df.head())
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Exercise 6: Now we can start analysing the data to get good understating of it.

# %%
# Display basic information about the dataset 
print("Shape of the DataFrame:") 
print(df.shape) 

print("\nColumns in the DataFrame:") 
print(df.columns)
# Out:
# Shape of the DataFrame:
# (395, 33)
#
# Columns in the DataFrame:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# ## Exercise 7: To get a statistical analysis of the data we can use pandas describe tool, as follows:

# %%
# Display summary statistics of numerical columns 
print("\nSummary Statistics:") 
display(df.describe())
# Out:
# Summary Statistics:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# std      0.896659    0.998862    1.113278    0.890741    1.287897    1.390303
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    3.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  395.000000  395.000000  395.000000  395.000000
# mean     5.708861   10.908861   10.713924   10.415190
# std      8.003096    3.319195    3.761505    4.581443
# min      0.000000    3.000000    0.000000    0.000000
# 25%      0.000000    8.000000    9.000000    8.000000
# 50%      4.000000   11.000000   11.000000   11.000000
# 75%      8.000000   13.000000   13.000000   14.000000
# max     75.000000   19.000000   19.000000   20.000000

# %% [markdown]
# ## Exercise 8: To check for any missing data, we can use:

# %%
# Check for any missing values 
print("\nMissing Values:") 
print(df.isnull().sum())
# Out:
# Missing Values:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
# Check for any missing values 
file_name = 'student-mat_edit.csv'

df = pd.read_csv(file_name, sep=';') 

print("\nMissing Values:") 
print(df.isnull().sum())
# Out:
# Missing Values:
# school        1
# sex           1
# age           0
# address       1
# famsize       1
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          1
# Fjob          0
# reason        2
# guardian      2
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      1
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            1
# G3            0
# dtype: int64

# %% [markdown]
# ## Exercise 9: To check for duplicated row, we can use:

# %%
# Check for any duplicate rows 
print("\nDuplicate Rows:") 
print(df.duplicated().sum())
# Out:
# Duplicate Rows:
# 0

# %%
# Check after adding a duplicated row
file_name = 'student-mat_edit.csv'

df = pd.read_csv(file_name, sep=';') 

print("\nDuplicate Rows:") 
print(df.duplicated().sum())
# Out:
# Duplicate Rows:
# 1

# %% [markdown]
# ## Exercise 10: To check for column data types, we can use:

# %%
print("\nData types of the columns:") 
print(df.dtypes)
# Out:
# Data types of the columns:
# school         object
# sex            object
# age             int64
# address        object
# famsize        object
# Pstatus        object
# Medu            int64
# Fedu            int64
# Mjob           object
# Fjob           object
# reason         object
# guardian       object
# traveltime      int64
# studytime       int64
# failures        int64
# schoolsup      object
# famsup         object
# paid           object
# activities     object
# nursery        object
# higher         object
# internet       object
# romantic       object
# famrel          int64
# freetime      float64
# goout           int64
# Dalc            int64
# Walc            int64
# health          int64
# absences        int64
# G1              int64
# G2            float64
# G3              int64
# dtype: object

# %% [markdown]
# Where: object = Non-primitive or Reference Data Type, int64 = 64 bit integer, float64 = 64 bit float

# %% [markdown]
# ## Exercise 11: We can asse the importance of the feature using the correlation matrix as follows:

# %%
import matplotlib.pyplot as plt

# Selecting only numerical columns 
numerical_columns = df.select_dtypes(include=['int64', 'float64']) 

# Calculating correlations 
correlations = numerical_columns.corr() 

# Creating a basic heatmap to visualize the correlations 
plt.figure(figsize=(10, 8)) 
plt.imshow(correlations, cmap='coolwarm', interpolation='nearest') 
plt.colorbar() 
plt.xticks(range(len(correlations)), correlations.columns, rotation=90) 
plt.yticks(range(len(correlations)), correlations.columns) 
plt.title('Correlation Heatmap of Student Performance Dataset') 
plt.show()

correlations
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# goout       0.126964  0.064094  0.043105    0.028540  -0.063904  0.124561
# Dalc        0.131125  0.019834  0.002386    0.138325  -0.196019  0.136047
# Walc        0.117276 -0.047123 -0.012631    0.134116  -0.253785  0.141962
# health     -0.062187 -0.046878  0.014742    0.007501  -0.075616  0.065827
# absences    0.175230  0.100285  0.024473   -0.012944  -0.062700  0.063726
# G1         -0.064081  0.205341  0.190270   -0.093040   0.160612 -0.354718
# G2         -0.143474  0.215527  0.164893   -0.153198   0.135880 -0.355896
# G3         -0.161579  0.217147  0.152457   -0.117142   0.097820 -0.360415
#
#               famrel  freetime     goout      Dalc      Walc    health  \
# age         0.053940  0.016434  0.126964  0.131125  0.117276 -0.062187
# Medu       -0.003914  0.030891  0.064094  0.019834 -0.047123 -0.046878
# Fedu       -0.001370 -0.012846  0.043105  0.002386 -0.012631  0.014742
# traveltime -0.016808 -0.017025  0.028540  0.138325  0.134116  0.007501
# studytime   0.039731 -0.143198 -0.063904 -0.196019 -0.253785 -0.075616
# failures   -0.044337  0.091987  0.124561  0.136047  0.141962  0.065827
# famrel      1.000000  0.150701  0.064568 -0.077594 -0.113397  0.094056
# freetime    0.150701  1.000000  0.285019  0.209001  0.147822  0.075733
# goout       0.064568  0.285019  1.000000  0.266994  0.420386 -0.009577
# Dalc       -0.077594  0.209001  0.266994  1.000000  0.647544  0.077180
# Walc       -0.113397  0.147822  0.420386  0.647544  1.000000  0.092476
# health      0.094056  0.075733 -0.009577  0.077180  0.092476  1.000000
# absences   -0.044354 -0.058078  0.044302  0.111908  0.136291 -0.029937
# G1          0.022168  0.012613 -0.149104 -0.094159 -0.126179 -0.073172
# G2         -0.018281 -0.013777 -0.162250 -0.064120 -0.084927 -0.097720
# G3          0.051363  0.011307 -0.132791 -0.054660 -0.051939 -0.061335
#
#             absences        G1        G2        G3
# age         0.175230 -0.064081 -0.143474 -0.161579
# Medu        0.100285  0.205341  0.215527  0.217147
# Fedu        0.024473  0.190270  0.164893  0.152457
# traveltime -0.012944 -0.093040 -0.153198 -0.117142
# studytime  -0.062700  0.160612  0.135880  0.097820
# failures    0.063726 -0.354718 -0.355896 -0.360415
# famrel     -0.044354  0.022168 -0.018281  0.051363
# freetime   -0.058078  0.012613 -0.013777  0.011307
# goout       0.044302 -0.149104 -0.162250 -0.132791
# Dalc        0.111908 -0.094159 -0.064120 -0.054660
# Walc        0.136291 -0.126179 -0.084927 -0.051939
# health     -0.029937 -0.073172 -0.097720 -0.061335
# absences    1.000000 -0.031003 -0.031777  0.034247
# G1         -0.031003  1.000000  0.852118  0.801468
# G2         -0.031777  0.852118  1.000000  0.904868
# G3          0.034247  0.801468  0.904868  1.000000

# %% [markdown]
# ## Exercise 12: To understand the different distributions

# %%
# Generate value counts for categorical variables 
print("\nValue Counts for Categorical Variables:") 
print(df['sex'].value_counts())
print()
print(df['address'].value_counts())
# Out:
# Value Counts for Categorical Variables:
# sex
# F    208
# M    187
# Name: count, dtype: int64
#
# address
# U    307
# R     88
# Name: count, dtype: int64

# %% [markdown]
# ## Exercise 13: We can easily visualise the data using matplotlib

# %%
import matplotlib.pyplot as plt 

# Example: Histogram of Age 
plt.figure(figsize=(8, 6)) 
plt.hist(df['age'], bins=20, color='skyblue', edgecolor='black') 
plt.title('Histogram of Age') 
plt.xlabel('Age') 
plt.ylabel('Frequency') 
plt.show()

# %% [markdown]
# ## Exercise 14:

# %%
import pandas as pd 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score 
import matplotlib.pyplot as plt
import numpy as np

# %%
# Selecting the feature and target variables 
X = df[['G1']] # Feature variable 
y = df['G3'] # Target variable

# Splitting the data into training and testing sets 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Creating and fitting the model 
model = LinearRegression() 
model.fit(X_train, y_train)

# Predicting the target values 
y_pred = model.predict(X_test)

# %% [markdown]
# ## Exercise 15: Measure the model performance using Mean Absolute Error, Mean Squared Error, and Calculating R-squared.

# %%
# Calculating Mean Absolute Error 
mae = mean_absolute_error(y_test, y_pred) 
print("Mean Absolute Error:", mae) 

# Calculating Mean Squared Error 
mse = mean_squared_error(y_test, y_pred) 
print("Mean Squared Error:", mse) 

# Calculating R-squared 
r2 = r2_score(y_test, y_pred) 
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 2.0107180614189373
# Mean Squared Error: 8.38800753657445
# R-squared: 0.6959638345717838

# %% [markdown]
# ## Exercise 16: Visualise the model performance

# %%
# Plotting the data points and the regression line 
plt.scatter(X_test, y_test, color='black', label='Actual data') 
plt.plot(X_test, y_pred, color='blue', linewidth=3, label='Regression line') 
plt.title('Single Variable Linear Regression') 
plt.xlabel('First Test Grade (G1)') 
plt.ylabel('Final Grade (G3)') 
plt.legend() 
plt.show()

# %% [markdown]
# ## Exercise 17: Try 3 different independent variables and compare the results. Write a comment on the best variable for the prediction (make sure that the variable you are testing is a numeric one as we cannot use a string as a number).

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# List of independent variables to test
independent_variables = ['freetime', 'health', 'absences']

# Dictionary to store the results
results = {}

for var in independent_variables:
    # Selecting the feature and target variables
    X = df[[var]]  # Feature variable
    y = df['G3']  # Target variable

    # Splitting the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

    # Creating and fitting the model
    model = LinearRegression()
    model.fit(X_train, y_train)

    # Predicting the target values
    y_pred = model.predict(X_test)

    # Evaluating the model
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Storing the results
    results[var] = {'MAE': mae, 'MSE': mse, 'R2': r2}

    # Print the performance metrics for each variable
    print(f"Performance for {var}:")
    print(f"Mean Absolute Error (MAE): {mae}")
    print(f"Mean Squared Error (MSE): {mse}")
    print(f"R-squared (R²): {r2} \n")

    # Plotting the data points and the regression line 
    plt.scatter(X_test, y_test, color='black', label='Actual data') 
    plt.plot(X_test, y_pred, color='blue', linewidth=3, label='Regression line') 
    plt.title('Single Variable Linear Regression') 
    plt.xlabel(f'Student\'s {var}') 
    plt.ylabel('Final Grade (G3)') 
    plt.legend() 
    plt.show()

    print()
# Out:
# Performance for freetime:
# Mean Absolute Error (MAE): 4.120199069566159
# Mean Squared Error (MSE): 27.694604563167537
# R-squared (R²): -0.0038333105593415517
# Performance for health:
# Mean Absolute Error (MAE): 4.103200033762309
# Mean Squared Error (MSE): 27.461399786160143
# R-squared (R²): 0.004619553348053751
# Performance for absences:
# Mean Absolute Error (MAE): 4.131640882715294
# Mean Squared Error (MSE): 27.60352661780969
# R-squared (R²): -0.0005320510956443592

# %% [markdown]
# ### Finding the best variable based on Mean Absolute Error (MAE)

# %%
# Finding the best variable based on Mean Absolute Error (MAE)
best_var_mae = min(results, key=lambda x: results[x]['MAE'])
print(f"The best variable for prediction based on MAE is {best_var_mae} with a MAE value of {results[best_var_mae]['MAE']}. \n")

# Plotting the actual vs predicted values for the best variable based on MAE
X = df[[best_var_mae]]
y = df['G3']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

plt.scatter(X_test, y_test, color='black', label='Actual values')
plt.plot(X_test, y_pred, color='blue', linewidth=2, label='Predicted values')
plt.title(f'Actual vs Predicted values for {best_var_mae}')
plt.xlabel(best_var_mae)
plt.ylabel('Final Grade (G3)')
plt.legend()
plt.show()
# Out:
# The best variable for prediction based on MAE is health with a MAE value of 4.103200033762309.

# %% [markdown]
# ### Finding the best variable based on Mean Squared Error (MSE)

# %%
# Finding the best variable based on Mean Squared Error (MSE)
best_var_mse = min(results, key=lambda x: results[x]['MSE'])
print(f"The best variable for prediction based on MSE is {best_var_mse} with a MSE value of {results[best_var_mse]['MSE']}. \n")

# Plotting the actual vs predicted values for the best variable based on MSE
X = df[[best_var_mse]]
y = df['G3']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

plt.scatter(X_test, y_test, color='black', label='Actual values')
plt.plot(X_test, y_pred, color='blue', linewidth=2, label='Predicted values')
plt.title(f'Actual vs Predicted values for {best_var_mse}')
plt.xlabel(best_var_mse)
plt.ylabel('Final Grade (G3)')
plt.legend()
plt.show()
# Out:
# The best variable for prediction based on MSE is health with a MSE value of 27.461399786160143.

# %% [markdown]
# ### Finding the best variable based on R-squared value

# %%
# Finding the best variable based on R-squared value
best_var_r2 = max(results, key=lambda x: results[x]['R2'])
print(f"The best variable for prediction based on R-squared is {best_var_r2} with an R-squared value of {results[best_var_r2]['R2']}. \n")

# Plotting the actual vs predicted values for the best variable based on R-squared
X = df[[best_var_r2]]
y = df['G3']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

plt.scatter(X_test, y_test, color='black', label='Actual values')
plt.plot(X_test, y_pred, color='blue', linewidth=2, label='Predicted values')
plt.title(f'Actual vs Predicted values for {best_var_r2}')
plt.xlabel(best_var_r2)
plt.ylabel('Final Grade (G3)')
plt.legend()
plt.show()
# Out:
# The best variable for prediction based on R-squared is health with an R-squared value of 0.004619553348053751.

# %% [markdown]
# Comment: According to the performance testing results, "health " can be assumed as the best independent variable for the prediction among these three independent variables: age, study time, and absences.

# %% [markdown]
# ## Exercise 18: Now we will use multiple features to predict the grade and compare the result to the single viable. To do so we need to redefine the X variable as follows. (Note: we cannot plot multidimensional plots, thus you should not plot the data as in exercise 16)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# Selecting the feature and target variables
X = df[['G1', 'G2', 'age', 'traveltime', 'studytime', 'failures']]
y = df['G3']  # Target variable

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Creating and fitting the model
model = LinearRegression()
model.fit(X_train, y_train)

# Predicting the target values
y_pred = model.predict(X_test)

# Calculating Mean Absolute Error
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)

# Calculating Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Calculating R-squared
r2 = r2_score(y_test, y_pred)
print("R-squared:", r2)

# Visualization: Actual vs Predicted Values with Line Plot
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, color='blue', label='Predicted vs Actual')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linewidth=2, label='Ideal Fit Line')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Multiple Variable Linear Regression')
plt.legend()
plt.show()
# Out:
# Mean Absolute Error: 1.3396503845046623
# Mean Squared Error: 5.4060302014231985
# R-squared: 0.804050165016772

# %% [markdown]
# ### Compare the result to the single viable

# %%
# Selecting the feature and target variables 
X = df[['age']] # Feature variable 
y = df['G3'] # Target variable

# Splitting the data into training and testing sets 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Creating and fitting the model 
model = LinearRegression() 
model.fit(X_train, y_train)

# Predicting the target values 
y_pred = model.predict(X_test)

# Calculating Mean Absolute Error 
mae = mean_absolute_error(y_test, y_pred) 
print("Mean Absolute Error:", mae) 

# Calculating Mean Squared Error 
mse = mean_squared_error(y_test, y_pred) 
print("Mean Squared Error:", mse) 

# Calculating R-squared 
r2 = r2_score(y_test, y_pred) 
print("R-squared:", r2)

# Plotting the data points and the regression line 
plt.scatter(X_test, y_test, color='black', label='Actual data') 
plt.plot(X_test, y_pred, color='blue', linewidth=3, label='Regression line') 
plt.title('Single Variable Linear Regression') 
plt.xlabel('Student\'s Age') 
plt.ylabel('Final Grade (G3)') 
plt.legend() 
plt.show()
# Out:
# Mean Absolute Error: 4.073007269405722
# Mean Squared Error: 27.605063800672415
# R-squared: -0.00058776864013943

# %% [markdown]
# By comparing the performance of a single-variable model (using just one feature) to a model with multiple features, we can see if using additional data points (features) improves the accuracy of predicting grades.

# %% [markdown]
# ### Look back at the corelation matrix and find the most useful features you may use to get best results.
# Based on the correlation matrix we got in Exercise 11, here are the correlations of each feature with G3:
# - G1 (Grade 1): 0.801468 (Moderate positive correlation)
# - G2 (Grade 2): 0.904868 (Strong positive correlation)
# - failures: -0.360415 (Strong negative correlation)
# - Medu (Mother's Education): 0.217147 (Weak to moderate positive correlation)
# - Fedu (Father's Education): 0.152457 (Weak positive correlation)
# - age: -0.161579 (Weak negative correlation)
# - goout: -0.132791 (Weak negative correlation)
# - Walc (Weekend Alcohol Consumption): -0.051939 (Weak negative correlation)
# - health: -0.061335 (Weak negative correlation)
# - absences: 0.034247 (Weak positive correlation)
# - studytime: 0.097820 (Weak positive correlation)
#
# Thus,
# - G2 (Grade 2): This feature has the highest correlation with G3, indicating it is the most influential predictor.
# - G1 (Grade 1): Also strongly correlates with G3, making it another highly useful predictor.
# - failures: Strong negative correlation suggests it strongly influences lower final grades.
# - Medu (Mother's Education): Moderate positive correlation suggests it contributes positively to higher final grades.
# - Fedu (Father's Education): Weak positive correlation, still contributing positively to final grades but less so than Medu.
# - age, goout, Walc, health, absences, studytime: These have weaker correlations but still provide some predictive value.
#
# Therefore, the features G2, G1, failures, Medu, and Fedu are the most useful predictors for G3 based on their correlations. These should be prioritized in our predictive modelling or analysis tasks related to final grades.

# %% [markdown]
# ## References
#
# Cortez, P., and Silva, A., 2014, 'Student Performance. UCI Machine Learning Repository', https://doi.org/10.24432/C5TG7T.
#
# Hackers Realm, 2023, 'Feature Selection using Correlation Matrix (Numerical),' Hackers Realm, 21 June. Available at: https://www.hackersrealm.net/post/feature-selection-using-correlation-matrix (Accessed: July 9, 2024).
#
# Python ML Daily, 2023, 'Course: Linear Regression in Python - Intro to Machine Learning', Available at: https://youtube.com/playlist?list=PLCVIwUQJ_a6x5M9mdhEpO_IdtFrRtAyaY&feature=shared (Accessed: July 9, 2024).
